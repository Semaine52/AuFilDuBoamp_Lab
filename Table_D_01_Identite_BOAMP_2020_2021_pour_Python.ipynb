# %% [markdown]
# <a href="https://colab.research.google.com/github/Semaine52/AuFilDuBoamp_Lab/blob/master/Table_D_01_Identite_BOAMP_2020_2021_pour_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Table __D_01_Identite__ BOAMP 2020-2021 pour Python

# %% [markdown]
# ### Infos liminaires

# %%
# %%html
# <iframe src="https://aufilduboamp.com/DOCS/NOTEBOOKS/GCOLABS/GCOLABS_INIT_CHAPEAU.html"
# style="width:95%; height:400px;"></iframe>
# Out:
# <iframe src="https://aufilduboamp.com/DOCS/NOTEBOOKS/GCOLABS/GCOLABS_INIT_CHAPEAU.html"
# style="width:95%; height:400px;"></iframe>

# %% [markdown]
# ### Schéma html interactif de la table
# Plein écran ► https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_01_identite.html

# %%
# %%html
# <iframe src="https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_01_identite.html"
# style="width:90%; height:400px;" ></iframe>
# Out:
# <iframe src="https://aufilduboamp.com/DOCS/BOAMP_ARBRES_HTML/boamp_plan_d_01_identite.html"
# style="width:90%; height:400px;" ></iframe>

# %% [markdown]
# ### Préparations

# %%
## Préparations 
# 1- Importer des packages/modules/classes depuis la bibliothèque standard
import sys
# 2- Importer des packages/modules/classes depuis des tiers
import pandas as pd
import altair as alt
from IPython.core.display import HTML, display
from IPython.core.interactiveshell import InteractiveShell
# 3- Importer des packages/modules/classes/variables depuis des modules maison
# !git clone https://github.com/Semaine52/AuFilDuBoamp_Outils_CSV.git;
sys.path.insert(0, '/content/AuFilDuBoamp_Outils_CSV') # Adapter au besoin
sys.path.insert(0, '/content/AuFilDuBoamp_Outils/afdb_outils_csv') # Adapter au besoin
from AuFilDuBoamp_Outils_CSV import afdb_outils_csv
from AuFilDuBoamp_Outils_CSV.afdb_outils_csv import BOAMP_ARBRES_HTML, BOAMP_2020_GITHUB_CSV, BOAMP_2021_GITHUB_CSV
# 4- Permettre des sorties multiples sous les cellules
InteractiveShell.ast_node_interactivity = "all"
# 5- Régler Pandas/Altair
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 2000)
# Versions des principaux outils utilisés
print(f"Version de Python -> {sys.version}")
print(f"Version de Pandas -> {pd.__version__}")
print(f"Version d'Altair  -> {alt.__version__}")
# Out:
# fatal: destination path 'AuFilDuBoamp_Outils_CSV' already exists and is not an empty directory.
# Version de Python -> 3.7.10 (default, May  3 2021, 02:48:31)
# [GCC 7.5.0]
# Version de Pandas -> 1.1.5
# Version d'Altair  -> 4.1.0

# %% [markdown]
# ### Création de la Dataframe «df» -> 5 lignes par année avec head() à adapter.

# %%
# CRÉATION DE LA DATAFRAME DF
## NOTEZ LES .head() en fin de ligne. Retirez-les pour charger toutes 
## les données des tables
df1 = pd.concat([pd.read_csv(x) for x in BOAMP_2020_GITHUB_CSV if 'D_01' in x]).head()
df2 = pd.concat([pd.read_csv(x) for x in BOAMP_2021_GITHUB_CSV if 'D_01' in x]).head()
df = pd.concat([df1, df2], axis=0).set_index('BOAMP_AVIS_NUM')

# %% [markdown]
# ### df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 07-127994 to 19-170952
# Data columns (total 24 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   D_01_01_Identite_Denomination                 10 non-null     object
#  1   D_01_02_Identite_Codeidentnational            10 non-null     object
#  2   D_01_03_Identite_Correspondant                5 non-null      object
#  3   D_01_04_Identite_Contact                      4 non-null      object
#  4   D_01_05_Identite_Adjudicateurnuts             5 non-null      object
#  5   D_01_06_Identite_Adresse                      10 non-null     object
#  6   D_01_07_Identite_Cp                           10 non-null     object
#  7   D_01_08_Identite_Ville                        10 non-null     object
#  8   D_01_09_Identite_Pays                         1 non-null      object
#  9   D_01_10_Identite_Tel                          7 non-null      object
#  10  D_01_11_Identite_Poste                        1 non-null      object
#  11  D_01_12_Identite_Fax                          4 non-null      object
#  12  D_01_13_Identite_Mel                          9 non-null      object
#  13  D_01_14_Identite_Url                          7 non-null      object
#  14  D_01_15_Identite_Urlprofilacheteur            7 non-null      object
#  15  D_01_16_Identite_Urlinformation               0 non-null      object
#  16  D_01_17_Identite_Urlparticipation             2 non-null      object
#  17  D_01_18_Identite_Urldocument                  3 non-null      object
#  18  D_01_19_Identite_Outillogiciel                0 non-null      object
#  19  D_01_20_Identite_Agitpourautrecompteoui       10 non-null     bool
#  20  D_01_21_Identite_Agitpourautrecomptenon       10 non-null     bool
#  21  D_01_22_Identite_Loicompteautrepays           0 non-null      object
#  22  D_01_23_Identite_Organismeacheteurcentraloui  10 non-null     bool
#  23  D_01_24_Identite_Organismeacheteurcentralnon  10 non-null     bool
# dtypes: bool(4), object(20)
# memory usage: 1.7+ KB

# %% [markdown]
# ### df.head()

# %%
df.head(10)
# Out:
#                         D_01_01_Identite_Denomination  \
# BOAMP_AVIS_NUM
# 07-127994       Communauté de Communes du Kochersberg
# 17-23813                        Créteil-Habitat-SEMIC
# 17-31705                        COMMUNE DE MONTICELLO
# 18-55590                            CCIT de l'Ardèche
# 18-78695                                         CNRS
# 11-116542                Ville de La Croix saint Ouen
# 21-37182           METROPOLE D AIX MARSEILLE PROVENCE
# 19-140862           Communauté d'Agglomération du Sud
# 19-141762                             Ville de Cholet
# 19-170952                  Métropole Nice Côte d'Azur
#
#                D_01_02_Identite_Codeidentnational  \
# BOAMP_AVIS_NUM
# 07-127994                                    None
# 17-23813                                     None
# 17-31705                                     None
# 18-55590                                     None
# 18-78695                                     None
# 11-116542                                    None
# 21-37182                                     None
# 19-140862                                    None
# 19-141762                                    None
# 19-170952                                    None
#
#                D_01_03_Identite_Correspondant  \
# BOAMP_AVIS_NUM
# 07-127994          M. Vogel Justin, Président
# 17-23813                                  NaN
# 17-31705                        joseph mattei
# 18-55590                       Bourne Thierry
# 18-78695                     MOUSSET Séverine
# 11-116542                      Jean Desessart
# 21-37182                                  NaN
# 19-140862                                 NaN
# 19-141762                                 NaN
# 19-170952                                 NaN
#
#                                                            D_01_04_Identite_Contact  \
# BOAMP_AVIS_NUM
# 07-127994                                                                       NaN
# 17-23813                                                     M le Directeur Général
# 17-31705                                                                        NaN
# 18-55590                                                                        NaN
# 18-78695                                                                        NaN
# 11-116542                                                                       NaN
# 21-37182                      Direction de la Commande Publique-Service des Marchés
# 19-140862       Direction de la Commande Publique, à l'attention de M. le Président
# 19-141762                                                                       NaN
# 19-170952                                                             Jérome GODARD
#
#                D_01_05_Identite_Adjudicateurnuts  \
# BOAMP_AVIS_NUM
# 07-127994                                    NaN
# 17-23813                                   FR107
# 17-31705                                     NaN
# 18-55590                                     NaN
# 18-78695                                     NaN
# 11-116542                                    NaN
# 21-37182                                   FRL04
# 19-140862                                  FRY40
# 19-141762                                  FRG02
# 19-170952                                  FRL03
#
#                                                        D_01_06_Identite_Adresse  \
# BOAMP_AVIS_NUM
# 07-127994       Le Trèfle, Maison des Services du Kochersberg32 rue des Romains
# 17-23813                                                      7, rue des Ecoles
# 17-31705                                                     lieu dit Chiosella
# 18-55590                                                 140 Chemin Saint Clair
# 18-78695                                3E, Avenue de la Recherche Scientifique
# 11-116542                                                    65 route Nationale
# 21-37182                                            58, Boulevard Charles Livon
# 19-140862                                         379 rue Hubert Delisle BP 437
# 19-141762                     Hôtel de Ville - Rue Saint Bonaventure - BP 32135
# 19-170952                                             5 rue de l'Hôtel de Ville
#
#                D_01_07_Identite_Cp D_01_08_Identite_Ville  \
# BOAMP_AVIS_NUM
# 07-127994                    67370          Truchtersheim
# 17-23813                     94048                Créteil
# 17-31705                     20220             Monticello
# 18-55590                     07000                 Privas
# 18-78695                     45071        ORLEANS CEDEX 2
# 11-116542                    60610    la croix saint ouen
# 21-37182                      None              Marseille
# 19-140862                    97838        Le Tampon Cedex
# 19-141762                    49300                 CHOLET
# 19-170952                    06364           Nice cedex 4
#
#                D_01_09_Identite_Pays   D_01_10_Identite_Tel  \
# BOAMP_AVIS_NUM
# 07-127994                        NaN         03-88-69-76-29
# 17-23813                         NaN                    NaN
# 17-31705                         NaN         04-95-60-05-71
# 18-55590                         NaN         04-75-88-07-07
# 18-78695                         NaN         02-38-25-52-00
# 11-116542                        NaN                    NaN
# 21-37182                         NaN    (+33) 4-91-99-99-00
# 19-140862                         RE  (+33) -02-62-57-97-77
# 19-141762                        NaN    (+33) 2-44-09-26-90
# 19-170952                        NaN                    NaN
#
#                D_01_11_Identite_Poste   D_01_12_Identite_Fax  \
# BOAMP_AVIS_NUM
# 07-127994                         NaN                    NaN
# 17-23813                          NaN                    NaN
# 17-31705                          NaN         04-95-60-17-77
# 18-55590                          NaN                    NaN
# 18-78695                         7814         02-38-69-70-31
# 11-116542                         NaN                    NaN
# 21-37182                          NaN    (+33) 4-91-99-71-96
# 19-140862                         NaN  (+33) -02-62-57-97-74
# 19-141762                         NaN                    NaN
# 19-170952                         NaN                    NaN
#
#                                      D_01_13_Identite_Mel  \
# BOAMP_AVIS_NUM
# 07-127994                          com.com@kochersberg.fr
# 17-23813               service.marche@creteil-habitat.com
# 17-31705                  mairie-de-monticello@wanadoo.fr
# 18-55590                    thierry.bourne@ardeche.cci.fr
# 18-78695                     severine.mousset@dr8.cnrs.fr
# 11-116542                                             NaN
# 21-37182        marches.marseilleprovence@ampmetropole.fr
# 19-140862                              juridique@casud.re
# 19-141762         marches-contrats@choletagglomeration.fr
# 19-170952            procedures.dsp-ppp@nicecotedazur.org
#
#                           D_01_14_Identite_Url  \
# BOAMP_AVIS_NUM
# 07-127994                                  NaN
# 17-23813        http://www.creteil-habitat.com
# 17-31705                                   NaN
# 18-55590             http://www.ardeche.cci.fr
# 18-78695           http://www.cnrs.dr8.cnrs.fr
# 11-116542                                  NaN
# 21-37182              https://ampmetropole.fr/
# 19-140862                  http://www.casud.re
# 19-141762                 http://www.cholet.fr
# 19-170952            http://www.e-marches06.fr
#
#                             D_01_15_Identite_Urlprofilacheteur  \
# BOAMP_AVIS_NUM
# 07-127994                      http://www.marches-securises.fr
# 17-23813                http://www.creteil-habitat-marches.com
# 17-31705                                                   NaN
# 18-55590                    http://www.marches.publics.gouv.fr
# 18-78695                                                   NaN
# 11-116542       https://marches-agglo-compiegne.safetender.com
# 21-37182                https://marchespublics.ampmetropole.fr
# 19-140862                        https://casud.achatpublic.com
# 19-141762                    http://www.anjoumarchespublics.fr
# 19-170952                                                  NaN
#
#                D_01_16_Identite_Urlinformation  \
# BOAMP_AVIS_NUM
# 07-127994                                  NaN
# 17-23813                                   NaN
# 17-31705                                   NaN
# 18-55590                                   NaN
# 18-78695                                   NaN
# 11-116542                                  NaN
# 21-37182                                   NaN
# 19-140862                                  NaN
# 19-141762                                  NaN
# 19-170952                                  NaN
#
#                      D_01_17_Identite_Urlparticipation  \
# BOAMP_AVIS_NUM
# 07-127994                                          NaN
# 17-23813        http://www.creteil-habitat-marches.com
# 17-31705                                           NaN
# 18-55590                                           NaN
# 18-78695                                           NaN
# 11-116542                                          NaN
# 21-37182                                           NaN
# 19-140862                                          NaN
# 19-141762            http://www.anjoumarchespublics.fr
# 19-170952                                          NaN
#
#                           D_01_18_Identite_Urldocument  \
# BOAMP_AVIS_NUM
# 07-127994                                          NaN
# 17-23813        http://www.creteil-habitat-marches.com
# 17-31705                                           NaN
# 18-55590                                           NaN
# 18-78695                                           NaN
# 11-116542                                          NaN
# 21-37182                                           NaN
# 19-140862                                          NaN
# 19-141762            http://www.anjoumarchespublics.fr
# 19-170952                    http://www.e-marches06.fr
#
#                D_01_19_Identite_Outillogiciel  \
# BOAMP_AVIS_NUM
# 07-127994                                 NaN
# 17-23813                                  NaN
# 17-31705                                  NaN
# 18-55590                                  NaN
# 18-78695                                  NaN
# 11-116542                                 NaN
# 21-37182                                  NaN
# 19-140862                                 NaN
# 19-141762                                 NaN
# 19-170952                                 NaN
#
#                 D_01_20_Identite_Agitpourautrecompteoui  \
# BOAMP_AVIS_NUM
# 07-127994                                         False
# 17-23813                                          False
# 17-31705                                          False
# 18-55590                                          False
# 18-78695                                          False
# 11-116542                                         False
# 21-37182                                          False
# 19-140862                                         False
# 19-141762                                         False
# 19-170952                                         False
#
#                 D_01_21_Identite_Agitpourautrecomptenon  \
# BOAMP_AVIS_NUM
# 07-127994                                         False
# 17-23813                                           True
# 17-31705                                          False
# 18-55590                                          False
# 18-78695                                          False
# 11-116542                                         False
# 21-37182                                           True
# 19-140862                                         False
# 19-141762                                          True
# 19-170952                                         False
#
#                D_01_22_Identite_Loicompteautrepays  \
# BOAMP_AVIS_NUM
# 07-127994                                      NaN
# 17-23813                                       NaN
# 17-31705                                       NaN
# 18-55590                                       NaN
# 18-78695                                       NaN
# 11-116542                                      NaN
# 21-37182                                       NaN
# 19-140862                                      NaN
# 19-141762                                      NaN
# 19-170952                                      NaN
#
#                 D_01_23_Identite_Organismeacheteurcentraloui  \
# BOAMP_AVIS_NUM
# 07-127994                                              False
# 17-23813                                               False
# 17-31705                                               False
# 18-55590                                               False
# 18-78695                                               False
# 11-116542                                              False
# 21-37182                                               False
# 19-140862                                              False
# 19-141762                                              False
# 19-170952                                              False
#
#                 D_01_24_Identite_Organismeacheteurcentralnon
# BOAMP_AVIS_NUM
# 07-127994                                              False
# 17-23813                                                True
# 17-31705                                               False
# 18-55590                                               False
# 18-78695                                               False
# 11-116542                                              False
# 21-37182                                                True
# 19-140862                                              False
# 19-141762                                               True
# 19-170952                                              False

# %% [markdown]
# ## À vous de jouer !

# %%
# C'EST PARTI!
