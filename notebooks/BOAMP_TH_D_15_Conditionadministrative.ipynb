# %%
# %run afdb_lab_scripts/afdb_lab_prereglages
# %run afdb_lab_scripts/afdb_lab_haut
# Out:
# <!DOCTYPE html>
#
# <html>
#
# <title>AuFilDuBoamp_Lab par Semaine52</title>
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <link rel="stylesheet" href="https://www.w3schools.com/w3css/4/w3.css">
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
# <script src='https://kit.fontawesome.com/a076d05399.js'></script>
#
#
# <body>
#
# <div class="w3-container">
#    <div class="w3-padding  w3-white w3-small">
#
#      <a href="https://github.com/Semaine52/AuFilDuBoamp_Lab" title="AuFilDuBoamp_Lab sur GitHub" alt="AuFilDuBoamp_Lab sur GitHub" class="w3-bar-item w3-button fas fa-share-square w3-small w3-white">&nbsp; AuFilDuBoamp_Lab sur GitHub</a>
#
#      <a href="https://twitter.com/AuFilDuBoamp" title="AuFilDuBoamp sur Twitter" alt="AuFilDuBoamp sur Twitter" class="w3-bar-item w3-button fas fa-share-square w3-small w3-white">&nbsp; sur Twitter</a>
#
#      <a href="https://www.data.gouv.fr/fr/organizations/aufilduboamp-1/" title="AuFilDuBoamp sur DataGouv.fr" alt="AuFilDuBoamp sur DataGouv.fr" class="w3-bar-item w3-button fas fa-share-square w3-small  w3-white">&nbsp; sur DataGouv.fr</a>
#
#           <a href="https://mybinder.org/v2/gh/Semaine52/AuFilDuBoamp_Lab/master?urlpath=lab/tree/notebooks/_Sommaire.ipynb" title="AuFilDuBoamp_Lab sur Binder" alt="AuFilDuBoamp_Lab sur Binder" class="w3-bar-item w3-button fas fa-share-square w3-small  w3-white">&nbsp; sur Binder</a>
#
#           <a href="https://teamopendata.org/u/semaine52_jmf/summary" title="Jean-Marie Falvet sur TeamOpenData" alt="Jean-Marie Falvet sur TeamOpenData" class="w3-bar-item w3-button fas fa-share-square w3-small  w3-white">&nbsp; chez TeamOpenData</a>
#
#
#
#
#          <a href="https://www.data.gouv.fr/fr/datasets/boamp/" title="Le BOAMP sur DataGouv.fr" alt="Le BOAMP sur DataGouv.fr" class="w3-bar-item w3-button fas fa-share-square w3-small w3-white">&nbsp; Le BOAMP sur DataGouv.fr</a>
#
#      <a href="https://www.boamp.fr/" title="BOAMP.fr" alt="BOAMP.fr"class="w3-bar-item w3-button fas fa-share-square w3-small  w3-white">BOAMP.fr</a>
#
#      <a href="https://www.legifrance.gouv.fr/affichCode.do?cidTexte=LEGITEXT000037701019" title="Accueil" alt="Accueil"class="w3-bar-item w3-button fas fa-share-square w3-small  w3-white">&nbsp; Code de la commande publique (Légifrance)</a>
#
#    </div>
#
#  </div>
#
#  <div class="w3-container">
#    <div><img class="w3-animate-right" src="design/AFDB_DOTS.svg" alt="AuFilDuBoamp_Lab" title="AuFilDuBoamp_Lab" style="width:40%"></div>
#
#    <div class="w3-padding w3-xlarge w3-white">
#
#
#
#      <a href="_Sommaire.ipynb" alt="Sommaire général" title="Sommaire général" class="w3-bar-item w3-button fa fa-list w3-large w3-amber">&nbsp; Lien vers le Sommaire général</a>
#      <a href="https://mybinder.org/v2/gh/Semaine52/AuFilDuBoamp_Lab/master?urlpath=lab/tree/notebooks/_Sommaire.ipynb" alt="Lancer Binder" title="Lancer Binder" class="w3-bar-item w3-button fa fa-arrow-right w3-large w3-teal">&nbsp; Lancer Binder</a>
#      <p style="font-size:16px; margin-top:5px">N'oubliez pas <strong>« Run All Cells »</strong> du menu <strong>« Run »</strong> pour activer les pages une fois sur Binder.</p>
#   </div>
#
#  </div>
#
# </body>
#
# </html>

# %% [markdown]
# <div id="navigation"></div>
#
# #### Un tour d'horizon des Tables du BOAMP
#
# À base des données recueillies en OpenData via l'API consacrée --> https://www.data.gouv.fr/fr/datasets/api-boamp-beta/
#
# ----
# <h1 style="font-size:60px;">Table D_15_Conditionadministrative</h1>
#
# ----

# %% [markdown]
# - **<a href="#navigation">Navigateur<a/>**
#     - **<a href="#chargement">Chargement de la table<a/>**
#     - **<a href="#schema">Schéma interactif de la table**
#     - **<a href="#infos">Présentation brute des colonnes<a/>**
#     - **<a href="#verticale">Vue verticale de la table<a/>**
#     - **<a href="#horizontale">Vue horizontale de la table<a/>**

# %% [markdown]
# <div id="chargement"></div>
#
# ## Chargement de la table

# %%
extrait_df_d_15_conditionadministrative = pd.read_pickle('data/df_boamp_2021_02_D_15_conditionadministrative.pkl')

# %% [markdown]
# <div id="schema"></div>
#
# ## Schéma interactif de la table

# %%
from afdb_lab_scripts.afficher_plan_html import afficher_plan_html
afficher_plan_html(source="boamp_plans_html/boamp_plan_d_15_conditionadministrative.html");
# Out:
# Output(layout=Layout(border='3px solid #cccccc', margin='20px 100px 20px 100px', max_width='80%', padding='10p…

# %% [markdown]
# [Ouvrir ce schéma en plein écran dans un nouvel onglet (cliquez sur « Trust HTML » s'il n'apparaît pas de lui-même à l'ouverture)](boamp_plans_html/boamp_plan_d_15_conditionadministrative.html)

# %% [markdown]
# **<a href="#navigation">Remonter<a/>**

# %% [markdown]
# <div id="infos"></div>
#
# ## Présentation brute des colonnes

# %%
extrait_df_d_15_conditionadministrative.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9119 entries, 19-138840 to 21-9966
# Data columns (total 22 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   D_15_01_Conditionadministrative_Referencemarche                           3461 non-null   object
#  1   D_15_02_Conditionadministrative_Etudesconcours                            7 non-null      object
#  2   D_15_03_Conditionadministrative_Recompenseslaureatoui                     79 non-null     object
#  3   D_15_04_Conditionadministrative_Recompensesaureatnon                      1 non-null      object
#  4   D_15_05_Conditionadministrative_Recompenseslaureat                        81 non-null     object
#  5   D_15_06_Conditionadministrative_Indemnisationparticipants                 34 non-null     object
#  6   D_15_07_Conditionadministrative_Conditionsremiseoffres                    800 non-null    object
#  7   D_15_08_Conditionadministrative_Conditionsetmodepaiementobtenirdocuments  412 non-null    object
#  8   D_15_09_Conditionadministrative_Datelimiteobtentiondocuments              241 non-null    object
#  9   D_15_10_Conditionadministrative_Documentpayantoui                         1 non-null      object
#  10  D_15_11_Conditionadministrative_Documentpayantnon                         367 non-null    object
#  11  D_15_12_Conditionadministrative_Persouvertureoffresoui                    259 non-null    object
#  12  D_15_13_Conditionadministrative_Persouvertureoffresnon                    2 non-null      object
#  13  D_15_14_Conditionadministrative_Datedebutattribution                      0 non-null      object
#  14  D_15_15_Conditionadministrative_Dateouvertureoffres                       2816 non-null   object
#  15  D_15_16_Conditionadministrative_Lieuouvertureoffres                       673 non-null    object
#  16  D_15_17_Conditionadministrative_Abandonsadoui                             0 non-null      object
#  17  D_15_18_Conditionadministrative_Abandonsadnon                             457 non-null    object
#  18  D_15_19_Conditionadministrative_Finattributionoui                         5 non-null      object
#  19  D_15_20_Conditionadministrative_Finattributionnon                         459 non-null    object
#  20  D_15_21_Conditionadministrative_Envoielectroniqueavecoutiloui             435 non-null    object
#  21  D_15_22_Conditionadministrative_Envoielectroniqueavecoutilnon             4375 non-null   object
# dtypes: object(22)
# memory usage: 1.6+ MB

# %% [markdown]
# **<a href="#navigation">Remonter<a/>**

# %% [markdown]
# <div id="verticale"></div>
#
# ## Vue verticale de la table

# %%
extrait_df_d_15_conditionadministrative.head(3).T
# Out:
# BOAMP_AVIS_NUM                                                                                                                                                                        19-138840  \
# D_15_01_Conditionadministrative_Referencemarche                                                                                                                                            None
# D_15_02_Conditionadministrative_Etudesconcours                                                                                                                                             None
# D_15_03_Conditionadministrative_Recompenseslaureatoui                                                                                                                                      None
# D_15_04_Conditionadministrative_Recompensesaureatnon                                                                                                                                       None
# D_15_05_Conditionadministrative_Recompenseslaureat                                                                                                                                         None
# D_15_06_Conditionadministrative_Indemnisationparticipants                                                                                                                                  None
# D_15_07_Conditionadministrative_Conditionsremiseoffres                                                                                                                                     None
# D_15_08_Conditionadministrative_Conditionsetmodepaiementobtenirdocuments                                                                                                                   None
# D_15_09_Conditionadministrative_Datelimiteobtentiondocuments                                                                                                                                NaN
# D_15_10_Conditionadministrative_Documentpayantoui                                                                                                                                          None
# D_15_11_Conditionadministrative_Documentpayantnon                                                                                                                                          None
# D_15_12_Conditionadministrative_Persouvertureoffresoui                                                                                                                                     None
# D_15_13_Conditionadministrative_Persouvertureoffresnon                                                                                                                                     None
# D_15_14_Conditionadministrative_Datedebutattribution                                                                                                                                       None
# D_15_15_Conditionadministrative_Dateouvertureoffres                                                                                                                                        None
# D_15_16_Conditionadministrative_Lieuouvertureoffres                                                                                                                                        None
# D_15_17_Conditionadministrative_Abandonsadoui                                                                                                                                              None
# D_15_18_Conditionadministrative_Abandonsadnon                                 <?xml version="1.0" encoding="UTF-16"?>\n<ABANDON_SAD_NON xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"/>
# D_15_19_Conditionadministrative_Finattributionoui                                                                                                                                          None
# D_15_20_Conditionadministrative_Finattributionnon                         <?xml version="1.0" encoding="UTF-16"?>\n<FIN_ATTRIBUTION_NON xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"/>
# D_15_21_Conditionadministrative_Envoielectroniqueavecoutiloui                                                                                                                              None
# D_15_22_Conditionadministrative_Envoielectroniqueavecoutilnon                                                                                                                              None
#
# BOAMP_AVIS_NUM                                                                                                                                                                        20-105937  \
# D_15_01_Conditionadministrative_Referencemarche                                                                                                                                            None
# D_15_02_Conditionadministrative_Etudesconcours                                                                                                                                             None
# D_15_03_Conditionadministrative_Recompenseslaureatoui                                                                                                                                      None
# D_15_04_Conditionadministrative_Recompensesaureatnon                                                                                                                                       None
# D_15_05_Conditionadministrative_Recompenseslaureat                                                                                                                                         None
# D_15_06_Conditionadministrative_Indemnisationparticipants                                                                                                                                  None
# D_15_07_Conditionadministrative_Conditionsremiseoffres                                                                                                                                     None
# D_15_08_Conditionadministrative_Conditionsetmodepaiementobtenirdocuments                                                                                                                   None
# D_15_09_Conditionadministrative_Datelimiteobtentiondocuments                                                                                                                                NaN
# D_15_10_Conditionadministrative_Documentpayantoui                                                                                                                                          None
# D_15_11_Conditionadministrative_Documentpayantnon                                                                                                                                          None
# D_15_12_Conditionadministrative_Persouvertureoffresoui                                                                                                                                     None
# D_15_13_Conditionadministrative_Persouvertureoffresnon                                                                                                                                     None
# D_15_14_Conditionadministrative_Datedebutattribution                                                                                                                                       None
# D_15_15_Conditionadministrative_Dateouvertureoffres                                                                                                                                        None
# D_15_16_Conditionadministrative_Lieuouvertureoffres                                                                                                                                        None
# D_15_17_Conditionadministrative_Abandonsadoui                                                                                                                                              None
# D_15_18_Conditionadministrative_Abandonsadnon                                 <?xml version="1.0" encoding="UTF-16"?>\n<ABANDON_SAD_NON xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"/>
# D_15_19_Conditionadministrative_Finattributionoui                                                                                                                                          None
# D_15_20_Conditionadministrative_Finattributionnon                         <?xml version="1.0" encoding="UTF-16"?>\n<FIN_ATTRIBUTION_NON xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"/>
# D_15_21_Conditionadministrative_Envoielectroniqueavecoutiloui                                                                                                                              None
# D_15_22_Conditionadministrative_Envoielectroniqueavecoutilnon                                                                                                                              None
#
# BOAMP_AVIS_NUM                                                                20-107212
# D_15_01_Conditionadministrative_Referencemarche                           DMORN-2020-21
# D_15_02_Conditionadministrative_Etudesconcours                                     None
# D_15_03_Conditionadministrative_Recompenseslaureatoui                              None
# D_15_04_Conditionadministrative_Recompensesaureatnon                               None
# D_15_05_Conditionadministrative_Recompenseslaureat                                 None
# D_15_06_Conditionadministrative_Indemnisationparticipants                          None
# D_15_07_Conditionadministrative_Conditionsremiseoffres                             None
# D_15_08_Conditionadministrative_Conditionsetmodepaiementobtenirdocuments           None
# D_15_09_Conditionadministrative_Datelimiteobtentiondocuments                        NaN
# D_15_10_Conditionadministrative_Documentpayantoui                                  None
# D_15_11_Conditionadministrative_Documentpayantnon                                  None
# D_15_12_Conditionadministrative_Persouvertureoffresoui                             None
# D_15_13_Conditionadministrative_Persouvertureoffresnon                             None
# D_15_14_Conditionadministrative_Datedebutattribution                               None
# D_15_15_Conditionadministrative_Dateouvertureoffres                                None
# D_15_16_Conditionadministrative_Lieuouvertureoffres                                None
# D_15_17_Conditionadministrative_Abandonsadoui                                      None
# D_15_18_Conditionadministrative_Abandonsadnon                                      None
# D_15_19_Conditionadministrative_Finattributionoui                                  None
# D_15_20_Conditionadministrative_Finattributionnon                                  None
# D_15_21_Conditionadministrative_Envoielectroniqueavecoutiloui                      None
# D_15_22_Conditionadministrative_Envoielectroniqueavecoutilnon                      None

# %% [markdown]
# **<a href="#navigation">Remonter<a/>**

# %% [markdown]
# <div id="horizontale"></div>
#
# ## Vue horizontale de la table

# %%
extrait_df_d_15_conditionadministrative.head(3)
# Out:
#                D_15_01_Conditionadministrative_Referencemarche  \
# BOAMP_AVIS_NUM
# 19-138840                                                 None
# 20-105937                                                 None
# 20-107212                                        DMORN-2020-21
#
#                D_15_02_Conditionadministrative_Etudesconcours  \
# BOAMP_AVIS_NUM
# 19-138840                                                None
# 20-105937                                                None
# 20-107212                                                None
#
#                D_15_03_Conditionadministrative_Recompenseslaureatoui  \
# BOAMP_AVIS_NUM
# 19-138840                                                       None
# 20-105937                                                       None
# 20-107212                                                       None
#
#                D_15_04_Conditionadministrative_Recompensesaureatnon  \
# BOAMP_AVIS_NUM
# 19-138840                                                      None
# 20-105937                                                      None
# 20-107212                                                      None
#
#                D_15_05_Conditionadministrative_Recompenseslaureat  \
# BOAMP_AVIS_NUM
# 19-138840                                                    None
# 20-105937                                                    None
# 20-107212                                                    None
#
#                D_15_06_Conditionadministrative_Indemnisationparticipants  \
# BOAMP_AVIS_NUM
# 19-138840                                                           None
# 20-105937                                                           None
# 20-107212                                                           None
#
#                D_15_07_Conditionadministrative_Conditionsremiseoffres  \
# BOAMP_AVIS_NUM
# 19-138840                                                        None
# 20-105937                                                        None
# 20-107212                                                        None
#
#                D_15_08_Conditionadministrative_Conditionsetmodepaiementobtenirdocuments  \
# BOAMP_AVIS_NUM
# 19-138840                                                                          None
# 20-105937                                                                          None
# 20-107212                                                                          None
#
#                D_15_09_Conditionadministrative_Datelimiteobtentiondocuments  \
# BOAMP_AVIS_NUM
# 19-138840                                                               NaN
# 20-105937                                                               NaN
# 20-107212                                                               NaN
#
#                D_15_10_Conditionadministrative_Documentpayantoui  \
# BOAMP_AVIS_NUM
# 19-138840                                                   None
# 20-105937                                                   None
# 20-107212                                                   None
#
#                D_15_11_Conditionadministrative_Documentpayantnon  \
# BOAMP_AVIS_NUM
# 19-138840                                                   None
# 20-105937                                                   None
# 20-107212                                                   None
#
#                D_15_12_Conditionadministrative_Persouvertureoffresoui  \
# BOAMP_AVIS_NUM
# 19-138840                                                        None
# 20-105937                                                        None
# 20-107212                                                        None
#
#                D_15_13_Conditionadministrative_Persouvertureoffresnon  \
# BOAMP_AVIS_NUM
# 19-138840                                                        None
# 20-105937                                                        None
# 20-107212                                                        None
#
#                D_15_14_Conditionadministrative_Datedebutattribution  \
# BOAMP_AVIS_NUM
# 19-138840                                                      None
# 20-105937                                                      None
# 20-107212                                                      None
#
#                D_15_15_Conditionadministrative_Dateouvertureoffres  \
# BOAMP_AVIS_NUM
# 19-138840                                                     None
# 20-105937                                                     None
# 20-107212                                                     None
#
#                D_15_16_Conditionadministrative_Lieuouvertureoffres  \
# BOAMP_AVIS_NUM
# 19-138840                                                     None
# 20-105937                                                     None
# 20-107212                                                     None
#
#                D_15_17_Conditionadministrative_Abandonsadoui  \
# BOAMP_AVIS_NUM
# 19-138840                                               None
# 20-105937                                               None
# 20-107212                                               None
#
#                                                                                     D_15_18_Conditionadministrative_Abandonsadnon  \
# BOAMP_AVIS_NUM
# 19-138840       <?xml version="1.0" encoding="UTF-16"?>\n<ABANDON_SAD_NON xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"/>
# 20-105937       <?xml version="1.0" encoding="UTF-16"?>\n<ABANDON_SAD_NON xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"/>
# 20-107212                                                                                                                    None
#
#                D_15_19_Conditionadministrative_Finattributionoui  \
# BOAMP_AVIS_NUM
# 19-138840                                                   None
# 20-105937                                                   None
# 20-107212                                                   None
#
#                                                                                     D_15_20_Conditionadministrative_Finattributionnon  \
# BOAMP_AVIS_NUM
# 19-138840       <?xml version="1.0" encoding="UTF-16"?>\n<FIN_ATTRIBUTION_NON xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"/>
# 20-105937       <?xml version="1.0" encoding="UTF-16"?>\n<FIN_ATTRIBUTION_NON xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"/>
# 20-107212                                                                                                                        None
#
#                D_15_21_Conditionadministrative_Envoielectroniqueavecoutiloui  \
# BOAMP_AVIS_NUM
# 19-138840                                                               None
# 20-105937                                                               None
# 20-107212                                                               None
#
#                D_15_22_Conditionadministrative_Envoielectroniqueavecoutilnon
# BOAMP_AVIS_NUM
# 19-138840                                                               None
# 20-105937                                                               None
# 20-107212                                                               None

# %% [markdown]
# **<a href="#navigation">Remonter<a/>**
